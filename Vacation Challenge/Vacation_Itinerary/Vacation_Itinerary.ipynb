# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(10)
# Out:
#    Unnamed: 0             City Country  Max Temp Current Description      Lat  \
# 0           0         Karratha      AU     82.78           clear sky -20.7377
# 1           1           Bonthe      SL     78.39           clear sky   7.5264
# 2           3           Bulolo      PG     83.08     overcast clouds  -7.2000
# 3           4        Cape Town      ZA     63.00          light rain -33.9258
# 4           7            Kapaa      US     80.01          light rain  22.0752
# 5           9         Victoria      HK     73.00     overcast clouds  22.2855
# 6          10  Manavalakurichi      IN     82.40                mist   8.1333
# 7          11      Port Alfred      ZA     69.37     overcast clouds -33.5906
# 8          13        Katherine      AU     86.00     overcast clouds -14.4667
# 9          17         Trinidad      BO     82.40    scattered clouds -14.8333
#
#         Lng                              Hotel Name
# 0  116.8463                    ibis Styles Karratha
# 1  -12.5050                  Bonthe Holiday Village
# 2  146.6500                       Pine Lodge Bulolo
# 3   18.4232       Southern Sun Waterfront Cape Town
# 4 -159.3190  Sheraton Kauai Resort at Coconut Beach
# 5  114.1577                      Mini Hotel Central
# 6   77.3000                       Udaya Boys Hostel
# 7   26.8910                      The Halyards Hotel
# 8  132.2667                         Pine Tree Motel
# 9  -64.9000                            Hotel Piesta

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
mexico_df = vacation_df.loc[(vacation_df["Country"] == "MX")]
mexico_df.dropna()
# Out:
#      Unnamed: 0              City Country  Max Temp Current Description   Lat  \
# 77          127        Coahuayana      MX     75.20       broken clouds 18.73
# 97          168  Puerto Escondido      MX     82.40    scattered clouds 15.85
# 103         183     Puerto Madero      MX     86.00       broken clouds 14.72
# 147         270              Puga      MX     80.60          few clouds 21.58
# 166         307             Azoyu      MX     80.80          few clouds 16.72
# 179         330              Ures      MX     73.99           clear sky 29.43
# 193         360           Cocorit      MX     73.40           clear sky 27.58
# 228         428           Camargo      MX     81.18    scattered clouds 27.67
# 237         448           Ojinaga      MX     86.00           clear sky 29.57
# 252         479    Cabo San Lucas      MX     77.00    scattered clouds 22.89
# 277         534    Guerrero Negro      MX     61.86           clear sky 27.98
# 318         605          Pochutla      MX     84.20    scattered clouds 15.74
# 334         642          Acapulco      MX     82.40    scattered clouds 16.86
#
#         Lng                         Hotel Name
# 77  -103.68  El rranchito michuacan de ocampos
# 97   -97.07      Aldea del Bazar Hotel and Spa
# 103  -92.42                   Hotel La Central
# 147 -104.82                            Del sol
# 166  -98.73                     Hotel San Luis
# 179 -110.40       Hotel HACIENDA San Francisco
# 193 -109.97                         Kaba Motel
# 228 -105.17                     Hotel Santa Fe
# 237 -104.42                  Suites Las Palmas
# 252 -109.91             Hotel Tesoro Los Cabos
# 277 -114.06       Casa Laguna, Bed & Breakfast
# 318  -96.47              Hotel Posada San Jose
# 334  -99.89          HS Hotsson Smart Acapulco

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"] == "Coahuayana")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"] == "Puerto Escondido")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"] == "Puerto Madero")]
vacation_stop3 = vacation_df.loc[(vacation_df["City"] == "Puga")] 
vacation_end = vacation_df.loc[(vacation_df["City"] == "Coahuayana")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.

start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')

# Get the lat and lng for the stops
coords_stop_1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
coords_stop_2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
coords_stop_3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Stop 1: {coords_stop_1}, Stop 2: {coords_stop_2}, Stop 3: {coords_stop_3}')
# Out:
# Start: (18.7333, -103.6833), End: (18.7333, -103.6833)
# Stop 1: (15.85, -97.0667), Stop 2: (14.7208, -92.4215), Stop 3: (21.5833, -104.8167)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

#Driving Directions
import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[coords_stop_1, coords_stop_2, coords_stop_3],
        travel_mode = "DRIVING")

fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.

combined_cities = [vacation_start, vacation_stop1, vacation_stop2, vacation_stop3]

four_cities_df = pd.concat(combined_cities, sort=False)
four_cities_df
# Out:
#      Unnamed: 0              City Country  Max Temp Current Description   Lat  \
# 77          127        Coahuayana      MX     75.20       broken clouds 18.73
# 97          168  Puerto Escondido      MX     82.40    scattered clouds 15.85
# 103         183     Puerto Madero      MX     86.00       broken clouds 14.72
# 147         270              Puga      MX     80.60          few clouds 21.58
#
#         Lng                         Hotel Name
# 77  -103.68  El rranchito michuacan de ocampos
# 97   -97.07      Aldea del Bazar Hotel and Spa
# 103  -92.42                   Hotel La Central
# 147 -104.82                            Del sol

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in four_cities_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = four_cities_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = four_cities_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
